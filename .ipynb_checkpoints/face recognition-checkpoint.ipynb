# %%
import cv2
import matplotlib.pyplot as plt

# %%
friend1_images = [
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 1\shubham 1.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 1\shubham 2.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 1\shubham 3.jpg"
]

f1 = []


for path in friend1_images:
    img = cv2.imread(path)
    
    img = cv2.resize(img, (256,256))  # Resize each image
    plt.matshow(img)  
    plt.title("Friend 1 - Sample Image")
    f1.append(img)
   

f1 = np.array(f1)  
print(f1.shape)
# Out:
# (3, 256, 256, 3)

# %%
friend2_images = [
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 2\abhay 1.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 2\abhay 2.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 2\abhay 3.jpg"
    
]
f2 = []
for path in friend2_images:
    img = cv2.imread(path)
    
    img = cv2.resize(img,(256,256))
    plt.matshow(img )
    plt.title("Friend 2 - Sample Image")
    f2.append(img)
    
       
f2 = np.array(f2)
print(f2.shape)

friend3_images = [
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 3\manish 1.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 3\manish 2.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 3\manish 3.jpg"
    
]
f3 = []


for path in friend3_images:
    img = cv2.imread(path)
    
    img = cv2.resize(img, (256,256))  # Resize each image
    plt.matshow(img)  
    plt.title("Friend 3 - Sample Image")
    f3.append(img)
   

f3 = np.array(f3)  
print(f3.shape) 


friend4_images = [
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 4\rishi 1.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 4\rishi 2.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 4\rishi 3.jpg"
    
]
f4 = []


for path in friend4_images:
    img = cv2.imread(path)
    
    img = cv2.resize(img, (256,256))  # Resize each image
    plt.matshow(img)  
    plt.title("Friend 4 - Sample Image")
    f4.append(img)
   

f4 = np.array(f4)  
print(f4.shape) 

friend5_images = [
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 5\karan 1.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 5\karan 2.jpg",
    r"C:\Users\DELL\OneDrive\Desktop\IIT-Bhu Iternship\Python\Jupyter Files\ML Project\Face Recognition\Friend 5\karan 3.jpg"
    
]
f5 = []


for path in friend5_images:
    img = cv2.imread(path)
    
    img = cv2.resize(img, (256,256))  # Resize each image
    plt.matshow(img)  
    plt.title("Friend 5 - Sample Image")
    f5.append(img)
   

f5 = np.array(f5)  
print(f5.shape)
# Out:
# (3, 256, 256, 3)
# (3, 256, 256, 3)
# (3, 256, 256, 3)
# (3, 256, 256, 3)

# %%
type(f3)
# Out:
# numpy.ndarray

# %%
f = np.concatenate([f1, f2, f3, f4, f5])
f
# Out:
# array([[[[192, 168, 148],
#          [191, 167, 147],
#          [193, 168, 148],
#          ...,
#          [255, 254, 254],
#          [255, 254, 254],
#          [255, 254, 254]],
#
#         [[191, 167, 147],
#          [194, 170, 150],
#          [193, 168, 149],
#          ...,
#          [255, 254, 254],
#          [255, 254, 254],
#          [255, 254, 254]],
#
#         [[179, 155, 136],
#          [175, 150, 130],
#          [174, 149, 129],
#          ...,
#          [255, 254, 254],
#          [255, 254, 254],
#          [255, 254, 254]],
#
#         ...,
#
#         [[229, 240, 248],
#          [229, 240, 248],
#          [230, 240, 249],
#          ...,
#          [242, 248, 253],
#          [242, 248, 253],
#          [243, 249, 254]],
#
#         [[221, 233, 245],
#          [218, 230, 242],
#          [212, 225, 236],
#          ...,
#          [243, 249, 254],
#          [239, 245, 250],
#          [239, 245, 250]],
#
#         [[216, 228, 240],
# ...

# %%
f.shape
# Out:
# (15, 256, 256, 3)

# %%
len(f)
# Out:
# 15

# %%
x=f.reshape(len(f),-1)
x.shape
# Out:
# (15, 196608)

# %%
x
# Out:
# array([[192, 168, 148, ..., 243, 249, 254],
#        [114, 160, 194, ..., 197, 206, 219],
#        [187, 223, 247, ..., 208, 220, 230],
#        ...,
#        [193, 170, 148, ...,  73,  71,  63],
#        [ 57,  96, 255, ..., 107, 129, 181],
#        [225, 229, 224, ...,  72,  81,  68]],
#       shape=(15, 196608), dtype=uint8)

# %%
y = np.array([0]*3 + [1]*3 + [2]*3 + [3]*3 + [4]*3)
y
# Out:
# array([0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4])

# %%
from sklearn.model_selection import train_test_split 
import warnings
warnings.filterwarnings("ignore")

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3,random_state=42)
len(train_x)
# Out:
# 10

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=1)
model.fit(train_x,train_y)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
m=model.predict(test_x)

# %%
test_y
# Out:
# array([3, 3, 0, 4, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, m)
# Out:
# 0.2
